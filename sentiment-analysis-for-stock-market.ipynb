# %% [markdown]
# <a href="https://www.kaggle.com/code/mahendrasinghrajpoot/sentiment-analysis-for-stock-market?scriptVersionId=98006568" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
#loading the dataset into the environment
news1 = pd.read_csv("../input/india-headlines-news-dataset/india-news-headlines.csv")
print("csv loaded successfully")
# Out:
# csv loaded successfully

# %%
#looking at the dataset to get an idea of it
news1.head()
# Out:
#    publish_date headline_category  \
# 0      20010102           unknown
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
news1.shape#finding the shape of the dataset
# Out:
# (3650970, 3)

# %%
news1['headline_category']#getting to know the category column
# Out:
# 0                                unknown
# 1                                unknown
# 2                                unknown
# 3                                unknown
# 4                                unknown
#                        ...
# 3650965                    city.srinagar
# 3650966    entertainment.hindi.bollywood
# 3650967                      city.trichy
# 3650968                       city.erode
# 3650969                       city.salem
# Name: headline_category, Length: 3650970, dtype: object

# %%
news1.dtypes #finding out the datatype of the value
# Out:
# publish_date          int64
# headline_category    object
# headline_text        object
# dtype: object

# %%
# converting the string to datetime format
news1['publish_date'] = pd.to_datetime(news1['publish_date'], format='%Y%m%d')
#so while selecting the column of the date we need to select the datetime in the proper format in order to get the datetime in the correct format

# %%
news1.head()
# Out:
#   publish_date headline_category  \
# 0   2001-01-02           unknown
# 1   2001-01-02           unknown
# 2   2001-01-02           unknown
# 3   2001-01-02           unknown
# 4   2001-01-02           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
news1.dtypes
# Out:
# publish_date         datetime64[ns]
# headline_category            object
# headline_text                object
# dtype: object

# %%
#finding how many columns are unknown in it
(news1["headline_category"]=="unknown").value_counts()
# Out:
# False    3441387
# True      209583
# Name: headline_category, dtype: int64

# %%
#need to remove the unkown values from the dataset
news1['publish_date']  = pd.to_datetime(news1['publish_date'])

# %%
news1.dtypes
# Out:
# publish_date         datetime64[ns]
# headline_category            object
# headline_text                object
# dtype: object

# %%
news1['publish_date'].head()
# Out:
# 0   2001-01-02
# 1   2001-01-02
# 2   2001-01-02
# 3   2001-01-02
# 4   2001-01-02
# Name: publish_date, dtype: datetime64[ns]

# %%
news1.iloc[0, 2]
# Out:
# 'Status quo will not be disturbed at Ayodhya; says Vajpayee'

# %%
news1.iloc[0, 2]
# Out:
# 'Status quo will not be disturbed at Ayodhya; says Vajpayee'

# %%
#providing the date time column to the dataframe
#news1['publish_date']  = pd.to_datetime(news1['publish_date'])

# %%
#news1['publish_date'] = news1['publish_date'].dt.strftime('%Y-%m-%d')#making the date in the right format

# %%
news1.head(5) #so finally our datetime has been converted into a string that we wanted it to convert
# Out:
#   publish_date headline_category  \
# 0   2001-01-02           unknown
# 1   2001-01-02           unknown
# 2   2001-01-02           unknown
# 3   2001-01-02           unknown
# 4   2001-01-02           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
#creating a copy of the dataframe
news1_copy = news1.copy()

# %%
#need to convert all the texts in the headline texts in the form of lower texts
#for i in news1['headline_text']:

# %%
#installing the model from the hugging face in order to analyze the dataset and the sentiment
#! pip install transformers

# %%
#from transformers import pipeline#importing pipeline from the transformers

# %%
#classifier = pipeline("zero-shot-classification", device=0)
