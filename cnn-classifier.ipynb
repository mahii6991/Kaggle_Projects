# %% [markdown]
# <a href="https://www.kaggle.com/code/mahendrasinghrajpoot/cnn-classifier?scriptVersionId=98692518" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Here we will be looking at the facemask dataset and will be applying the machine learning algorithm in it

# %% [markdown]
# Our task is to build the model that can classify the images in different categories

# %% [markdown]
# # Loading the libraries and defining some dependencies that we will going to use in our model

# %%
import numpy as np
import pandas as pd

import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense,Activation,Layer,Lambda

from sklearn.model_selection import train_test_split

# %%
#defining some functions beforehand that we will be using in the later chapeter
#defining the softmax function
def softmax(x):
    e=np.exp(x)
    return e/e.sum()

# %%
#lets pass a vector to see it works well or not
a = [ ]

# %% [markdown]
# > I need to start with the function that can help me to reshape the size of the image
# > and need to develop the function out of it.

# %%
#we will be calling it the reshaping the array and using in out model that we will going to built out of it.
#the image is shaped in the three channel and we need to make the 1 channel out of those 3 channel.
#so in order to reshape the array we need to use the
