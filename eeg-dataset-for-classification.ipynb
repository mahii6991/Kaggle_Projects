# %% [markdown]
# <a href="https://www.kaggle.com/code/mahendrasinghrajpoot/eeg-dataset-for-classification?scriptVersionId=100438433" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# > In this dataset we will going to use the eeg dataset to classiy the predictor variable into classes.

# %%
from scipy.io import arff
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

data = arff.loadarff('../input/eye-state-classification-eeg-dataset/EEG Eye State.arff')
df = pd.DataFrame(data[0])

df.head()
# Out:
#        AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0  4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1  4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2  4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3  4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4  4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
#
#         P8       T8      FC6       F4       F8      AF4 eyeDetection
# 0  4222.05  4238.46  4211.28  4280.51  4635.90  4393.85         b'0'
# 1  4210.77  4226.67  4207.69  4279.49  4632.82  4384.10         b'0'
# 2  4207.69  4222.05  4206.67  4282.05  4628.72  4389.23         b'0'
# 3  4217.44  4235.38  4210.77  4287.69  4632.31  4396.41         b'0'
# 4  4210.77  4244.10  4212.82  4288.21  4632.82  4398.46         b'0'

# %%
df.shape
# Out:
# (14980, 15)

# %%
df.dtypes
# Out:
# AF3             float64
# F7              float64
# F3              float64
# FC5             float64
# T7              float64
# P7              float64
# O1              float64
# O2              float64
# P8              float64
# T8              float64
# FC6             float64
# F4              float64
# F8              float64
# AF4             float64
# eyeDetection     object
# dtype: object

# %%
df.describe()
# Out:
#                  AF3            F7            F3            FC5            T7  \
# count   14980.000000  14980.000000  14980.000000   14980.000000  14980.000000
# mean     4321.917777   4009.767694   4264.022433    4164.946326   4341.741075
# std      2492.072174     45.941672     44.428052    5216.404632     34.738821
# min      1030.770000   2830.770000   1040.000000    2453.330000   2089.740000
# 25%      4280.510000   3990.770000   4250.260000    4108.210000   4331.790000
# 50%      4294.360000   4005.640000   4262.560000    4120.510000   4338.970000
# 75%      4311.790000   4023.080000   4270.770000    4132.310000   4347.180000
# max    309231.000000   7804.620000   6880.510000  642564.000000   6474.360000
#
#                   P7             O1            O2             P8  \
# count   14980.000000   14980.000000  14980.000000   14980.000000
# mean     4644.022379    4110.400160   4616.056904    4218.826610
# std      2924.789537    4600.926543     29.292603    2136.408523
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14980 entries, 0 to 14979
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AF3           14980 non-null  float64
#  1   F7            14980 non-null  float64
#  2   F3            14980 non-null  float64
#  3   FC5           14980 non-null  float64
#  4   T7            14980 non-null  float64
#  5   P7            14980 non-null  float64
#  6   O1            14980 non-null  float64
#  7   O2            14980 non-null  float64
#  8   P8            14980 non-null  float64
#  9   T8            14980 non-null  float64
#  10  FC6           14980 non-null  float64
#  11  F4            14980 non-null  float64
#  12  F8            14980 non-null  float64
#  13  AF4           14980 non-null  float64
#  14  eyeDetection  14980 non-null  object
# dtypes: float64(14), object(1)
# memory usage: 1.7+ MB

# %%
14980/117
#here we can say that there are 128 frequency it means that in 1 sec we are getting around 128 datapoints from the eeg data
# Out:
# 128.03418803418805

# %%
df.describe(include=object) #here we can see the count of the variable and how many unique values does it contains in it, and what are the top values in it and what is there frequency.
# Out:
#        eyeDetection
# count         14980
# unique            2
# top            b'0'
# freq           8257

# %%
df['eyeDetection'].value_counts()
# Out:
# b'0'    8257
# b'1'    6723
# Name: eyeDetection, dtype: int64

# %%
#here we will be replacing the values that are provided by the classification task into the simplified form
df['eyeDetection'] = df['eyeDetection'].replace({b'0' : 0 , b'1' :1})

# %%
#checking the results of the above code
df.tail()
# Out:
#            AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 14975  4281.03  3990.26  4245.64  4116.92  4333.85  4614.36  4074.87  4625.64
# 14976  4276.92  3991.79  4245.13  4110.77  4332.82  4615.38  4073.33  4621.54
# 14977  4277.44  3990.77  4246.67  4113.85  4333.33  4615.38  4072.82  4623.59
# 14978  4284.62  3991.79  4251.28  4122.05  4334.36  4616.41  4080.51  4628.72
# 14979  4287.69  3997.44  4260.00  4121.03  4333.33  4616.41  4088.72  4638.46
#
#             P8       T8      FC6       F4       F8      AF4  eyeDetection
# 14975  4203.08  4221.54  4171.28  4269.23  4593.33  4340.51             1
# 14976  4194.36  4217.44  4162.56  4259.49  4590.26  4333.33             1
# 14977  4193.33  4212.82  4160.51  4257.95  4591.79  4339.49             1
# 14978  4200.00  4220.00  4165.64  4267.18  4596.41  4350.77             1
# 14979  4212.31  4226.67  4167.69  4274.36  4597.95  4350.77             1

# %%
#checking out if the values are correctly replaced or not
df['eyeDetection'].value_counts() #so we have correctly replaced the values with the interger 1 and 0
# Out:
# 0    8257
# 1    6723
# Name: eyeDetection, dtype: int64

# %%
#checking if there are any missing values in the dataset
df.isnull().sum()
# Out:
# AF3             0
# F7              0
# F3              0
# FC5             0
# T7              0
# P7              0
# O1              0
# O2              0
# P8              0
# T8              0
# FC6             0
# F4              0
# F8              0
# AF4             0
# eyeDetection    0
# dtype: int64

# %%
#now we will be doing some of the visualization to find out the features of the different columns in our dataset
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


data_1 = df.copy()

# %%
data_1.head()
# Out:
#        AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0  4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1  4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2  4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3  4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4  4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
#
#         P8       T8      FC6       F4       F8      AF4  eyeDetection
# 0  4222.05  4238.46  4211.28  4280.51  4635.90  4393.85             0
# 1  4210.77  4226.67  4207.69  4279.49  4632.82  4384.10             0
# 2  4207.69  4222.05  4206.67  4282.05  4628.72  4389.23             0
# 3  4217.44  4235.38  4210.77  4287.69  4632.31  4396.41             0
# 4  4210.77  4244.10  4212.82  4288.21  4632.82  4398.46             0

# %%
data_1.drop('eyeDetection',axis=1,inplace=True)

# %%
data_1.head()
# Out:
#        AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0  4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1  4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2  4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3  4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4  4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
#
#         P8       T8      FC6       F4       F8      AF4
# 0  4222.05  4238.46  4211.28  4280.51  4635.90  4393.85
# 1  4210.77  4226.67  4207.69  4279.49  4632.82  4384.10
# 2  4207.69  4222.05  4206.67  4282.05  4628.72  4389.23
# 3  4217.44  4235.38  4210.77  4287.69  4632.31  4396.41
# 4  4210.77  4244.10  4212.82  4288.21  4632.82  4398.46

# %% [markdown]
# # EDA USING  Data Visualization

# %%
sns.set_theme(style='darkgrid')
for col in df.columns[0:-1]:
    plt.figure(figsize=(12, 5))
    sns.lineplot(x=df.index, y=col, data=df, hue="eyeDetection")
    plt.show()

# %%
#looping all the column for the boxplot and creating the boxplot out of it.
for column in data_1:
        plt.figure(figsize=(17,1))
        sns.boxplot(data=data_1, x=column)

# %%
#as we can see in the above diagram there are number of outliers present in out dataset

# %% [markdown]
# > As we can see in the above diagram there are number of outliers present in out dataset. so here we will taking the following steps when moving forward.
# 1. First we will running the model without removing the outliers and checking the testing the training accuracy.
# 2.  Next we will be removing the outliers from our dataset and checking the testing the training accuracy of different model and if removing the outliers will affect the accuracy of our models.

# %%
#creating the training and testing samples of the dataset
X = data_1.copy()
y = df['eyeDetection'].copy()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
#splitting the dataset into the testing and the training form
X_train, X_test, y_train, y_test = train_test_split(StandardScaler().fit_transform(X), y, test_size=0.33, random_state=42)

# %%
#loading the model 
Mymodel = LogisticRegression()

Mymodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#let's predict it on the test set
y_pred = Mymodel.predict(X_test)

# %%
from sklearn import metrics

Myconfusion = metrics.confusion_matrix(y_pred,y_test)

# %%
print(Myconfusion)
# Out:
# [[2124 1569]
#  [ 518  733]]

# %%
print("Accuracy",metrics.accuracy_score(y_pred,y_test)) #this is fro the testing accuracy.
# Out:
# Accuracy 0.5778721682847896

# %%
print("Accuracy",metrics.accuracy_score(Mymodel.predict(X_train),y_train)) ##this is for the training accuracy.
# Out:
# Accuracy 0.5918692706257473

# %%
#now here we will be trying to plot the ROC curve
ypred_prob = Mymodel.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  ypred_prob)
auc = metrics.roc_auc_score(y_test, ypred_prob)
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# > Here we will be first doing the fit and transform on the training dataset and only transform on the test dataset

# %%
#splitting the dataset into the testing and the training form
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
scale =  StandardScaler()

# %%
X_train_scale = scale.fit_transform(X_train)
X_test_scale = scale.transform(X_test)

# %%
#loading the model 
Mymodel = LogisticRegression(random_state = 56)

train_model =  Mymodel.fit(X_train_scale,y_train)

# %%
print("Accuracy of the logisitc regrssion model on training data %:",metrics.accuracy_score(Mymodel.predict(X_train_scale),y_train) * 100) ##this is for the training accuracy.
print("Accuracy of the logisitc regrssion model on testing data %:",metrics.accuracy_score(Mymodel.predict(X_test_scale),y_test) * 100) ##this is for the training accuracy.
# Out:
# Accuracy of the logisitc regrssion model on training data %: 59.279038718291055
# Accuracy of the logisitc regrssion model on testing data %: 56.84245660881175

# %%
#now finding out the total number of outliers feature wise and the datawise
import statsmodels.api as sm

# %%
y_train.values.reshape(-1,1)
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
#spector_data = sm.datasets.spector.load_pa
#model_sm = sm.Logit(X_train_scale.endog,y_train.exog)

# %%
from sklearn.tree import DecisionTreeClassifier ,plot_tree
from sklearn.model_selection import train_test_split , cross_val_score
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# # SVM / support vector Machine or support vector classifier

# %%
from sklearn import svm
from sklearn.svm import SVC
#let's code for the support vector machine 
my_svm = SVC(gamma = 'auto',kernel= 'linear',probability= True)

#NOW WE WILL BE FITTING THE DATASET INTO THE MODEL
my_svm.fit(X_train_scale,y_train)
# Out:
# SVC(gamma='auto', kernel='linear', probability=True)

# %%
#prediction 
y_pred = my_svm.predict(X_test_scale)

# %%
#Evaluation
precision = metrics.accuracy_score(y_pred,y_test) * 100
print("Accuracy of the above modelling withe the svm is {0:.2f}%".format(precision))
# Out:
# Accuracy of the above modelling withe the svm is 58.21%

# %%
plot_confusion_matrix(my_svm, X_test_scale, y_test)  
plt.show()

# %% [markdown]
# # knn or K-nearest neighbors

# %%
#now running the knn on the above model to find the accuracy of the model
from sklearn.neighbors import KNeighborsClassifier

#feeding the dataset to the model
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train_scale,y_train)

#prediction with the above model
y_pred = knn.predict(X_test_scale)

#Evaluating the model
precision = metrics.accuracy_score(y_pred,y_test) * 100
print("Accuracy of the model using the KNN : {0:.2f}%".format(precision))
# Out:
# Accuracy of the model using the KNN : 78.84%

# %% [markdown]
# # DecisionTree

# %%
#now checking the accuracy on the decision tree classification
my_tree = DecisionTreeClassifier()
my_tree = my_tree.fit(X_train_scale,y_train)
#predicting
y_pred = my_tree.predict(X_test_scale) 
#Evaluating the model
precision = metrics.accuracy_score(y_pred,y_test)* 100
#print  the accuracy
print("Accuracy of the model by using the decision tree algorithm : {0:.2f}%".format(precision))
# Out:
# Accuracy of the model by using the decision tree algorithm : 84.11%

# %%
#running the decision tree algorithm with the kfold cross validation
pred_k_fold = cross_val_score(my_tree, X, y , cv= 5)
print("Accuracy with the k-fold and cross validation is:%0.2f (+/- %0.2f)" % (pred_k_fold.mean(),pred_k_fold.std()* 2))
# Out:
# Accuracy with the k-fold and cross validation is:0.47 (+/- 0.11)

# %% [markdown]
# # Visualizing decision trees

# %%
plt.figure(figsize=(4,4),dpi=1000)
plot_tree(my_tree,filled= True)
plt.show()

# %%
#changing the max_depth
score_train = []
score_test = []

#now we will going to loop the depth of decision tree to work out for different decision trees that we will going to find
for i in range(1,10):
    tree_1 = DecisionTreeClassifier(max_depth=i)
    tree_1.fit(X_train_scale,y_train)
    
    
    #scoring both the tress and finding out the accuracy using the train and the test dataset
    score_train.append(tree_1.score(X_train_scale,y_train))
    score_test.append(tree_1.score(X_test_scale,y_test))
    
    
score_train_array = np.asarray(score_train)
score_test_array = np.asarray(score_test)
#defining the size of the figure
plt.figure(figsize=(10,6))
plt.plot(range(1,10),score_train_array,color='blue',label='training accuracy')
plt.plot(range(1,10),score_test_array,color='red',label='testing accuracy')



plt.legend()
plt.xlabel('max-depth')
plt.ylabel('Accuracy%')
plt.show()

# %% [markdown]
# # how the concept of the precision and recall works .?

# %% [markdown]
# Here we need to look out for the different components of the confusion matrix that we get from the model
# * the accuracy of the model is defined as the combination of score of TPR(true positive rate) and FPR(false positive rate), the combination of both the score should be high.
# * we should also know what are the terms that we use as the precision and recall
# 1. precision can be termed as - True positive / predicted positive
# 2. recall can be termed as - True positive / actual positive
#
# * now things will get interesting when we try to predict the f-1 score which is f1 = 2* (precision * recall) / (precision + recall)
